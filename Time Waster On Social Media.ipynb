# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:/Abhay/Datasets/Time-Wasters on Social Media.csv")
df.head(2)
# Out:
#    UserID  Age  Gender  Location  Income   Debt  Owns Property Profession  \
# 0       1   56    Male  Pakistan   82812   True           True   Engineer
# 1       2   46  Female    Mexico   27999  False           True     Artist
#
#   Demographics   Platform  ...  ProductivityLoss  Satisfaction  \
# 0        Rural  Instagram  ...                 3             7
# 1        Urban  Instagram  ...                 5             5
#
#       Watch Reason  DeviceType       OS  Watch Time  Self Control  \
# 0  Procrastination  Smartphone  Android     9:00 PM             5
# 1            Habit    Computer  Android     5:00 PM             7
#
#    Addiction Level  CurrentActivity  ConnectionType
# 0                5        Commuting     Mobile Data
# 1                3        At school           Wi-Fi
#
# [2 rows x 31 columns]

# %%
df.shape
# Out:
# (1000, 31)

# %%
df.isnull().sum()
# Out:
# UserID                      0
# Age                         0
# Gender                      0
# Location                    0
# Income                      0
# Debt                        0
# Owns Property               0
# Profession                  0
# Demographics                0
# Platform                    0
# Total Time Spent            0
# Number of Sessions          0
# Video ID                    0
# Video Category              0
# Video Length                0
# Engagement                  0
# Importance Score            0
# Time Spent On Video         0
# Number of Videos Watched    0
# Scroll Rate                 0
# Frequency                   0
# ProductivityLoss            0
# Satisfaction                0
# Watch Reason                0
# DeviceType                  0
# OS                          0
# Watch Time                  0
# Self Control                0
# Addiction Level             0
# CurrentActivity             0
# ConnectionType              0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# UserID                      1000
# Age                           47
# Gender                         3
# Location                      10
# Income                       996
# Debt                           2
# Owns Property                  2
# Profession                     9
# Demographics                   2
# Platform                       4
# Total Time Spent             278
# Number of Sessions            19
# Video ID                     947
# Video Category                 9
# Video Length                  29
# Engagement                   953
# Importance Score               9
# Time Spent On Video           29
# Number of Videos Watched      49
# Scroll Rate                   99
# Frequency                      4
# ProductivityLoss               9
# Satisfaction                   9
# Watch Reason                   4
# DeviceType                     3
# OS                             4
# Watch Time                    16
# Self Control                   8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   UserID                    1000 non-null   int64
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   object
#  3   Location                  1000 non-null   object
#  4   Income                    1000 non-null   int64
#  5   Debt                      1000 non-null   bool
#  6   Owns Property             1000 non-null   bool
#  7   Profession                1000 non-null   object
#  8   Demographics              1000 non-null   object
#  9   Platform                  1000 non-null   object
#  10  Total Time Spent          1000 non-null   int64
#  11  Number of Sessions        1000 non-null   int64
#  12  Video ID                  1000 non-null   int64
#  13  Video Category            1000 non-null   object
# ...

# %%
df.describe()
# Out:
#             UserID          Age        Income  Total Time Spent  \
# count  1000.000000  1000.000000   1000.000000       1000.000000
# mean    500.500000    40.986000  59524.213000        151.406000
# std     288.819436    13.497852  23736.212925         83.952637
# min       1.000000    18.000000  20138.000000         10.000000
# 25%     250.750000    29.000000  38675.250000         78.000000
# 50%     500.500000    42.000000  58805.000000        152.000000
# 75%     750.250000    52.000000  79792.250000        223.000000
# max    1000.000000    64.000000  99676.000000        298.000000
#
#        Number of Sessions     Video ID  Video Length   Engagement  \
# count         1000.000000  1000.000000   1000.000000  1000.000000
# mean            10.013000  4891.738000     15.214000  4997.159000
# std              5.380314  2853.144258      8.224953  2910.053701
# min              1.000000    11.000000      1.000000    15.000000
# ...

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      514
# Female    322
# Other     164
# Name: count, dtype: int64

# %%
ax = sns.countplot(data=df, x="Gender", hue="Platform")
plt.title("Count of Gender Via Platforms")

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# as we can see above chart in which male use much tik tok, instagram and you tube as comper to other categories of gender.

# %%
ax = sns.countplot(data =df ,y="Profession", hue="Demographics")

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# Social Media are used much by students who are from rural realm.

# %%
plt.figure(figsize=(10,4))
ax = sns.countplot(data=df, x="Location", hue="Platform")
plt.title("Count of Location VS Platforms")

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# Social media are much more used by india where most of people who use much tik tok in catgories of platform.

# %%
gb= df.groupby("Debt")["Debt"].count()
gb
# Out:
# Debt
# False    401
# True     599
# Name: Debt, dtype: int64

# %%
plt.figure(figsize=(3,4))
plt.pie(gb.values, labels=gb.index, autopct= "%0.2f%%")
plt.title("Debt")
plt.show()

# %%
ax = sns.countplot(data=df, x="Platform", hue="DeviceType")
plt.legend(bbox_to_anchor=(1,1))

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# Here, we can see that most of people who use smartphone to spend time on Social Media Platform.

# %%
plt.figure(figsize=(9,3))
sns.lineplot(data=df, x="Profession", y="Total Time Spent", marker="^")
plt.title("Profession VS Total Time Spent")

plt.show()

# %% [markdown]
# so, cashier spent much more time on the social media platform.

# %%
df["Number of Sessions"].unique()
# Out:
# array([17, 14,  6, 19, 18,  5,  2,  8, 15, 11,  1, 12,  7, 10,  3, 13,  4,
#        16,  9])

# %%
plt.figure(figsize=(11,3))
ax = sns.countplot(data=df, x="Video Category")

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# so, jokes/memes are most watched video category on the social media.

# %%
plt.figure(figsize=(11,4))
ax = sns.lineplot(data=df, y="Importance Score", x="Video Category", marker="^")

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# so, as we can see above charts that gaming is most importance to user.

# %%
plt.figure(figsize=(11,4))
ax = sns.barplot(data=df, x="Video Category", y="Engagement", errorbar=("ci",0))

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# so, trends are more engaged video category by user.

# %%
plt.figure(figsize=(11,4))
ax = sns.lineplot(data=df, y="Time Spent On Video", x="Video Category", marker="^")

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# pranks are most time spent video on the social media.

# %%
plt.figure(figsize=(11,4))
ax = sns.barplot(data=df, y="Number of Videos Watched", x="Video Category", errorbar=("ci",0))

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# no of videos of comedy are much watched by user.

# %%
sns.countplot(data=df, x="Frequency", hue="Platform")
# Out:
# <Axes: xlabel='Frequency', ylabel='count'>

# %% [markdown]
# so, most of people much used social media plaform at evening.

# %%
df["ProductivityLoss"].value_counts()
# Out:
# ProductivityLoss
# 6    247
# 3    228
# 5    158
# 8    145
# 7     60
# 1     55
# 9     37
# 4     36
# 2     34
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,4))
ax= sns.barplot(data=df, y="ProductivityLoss", x="Platform", errorbar=("ci",0))

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# the people who losed more productivity by seeing youtube.

# %%
ax = sns.lineplot(data=df, y="Satisfaction", x="Platform", marker="^")

# %% [markdown]
# facebook & instagram are much more satisfied by user.

# %%
a = df["Watch Time"].value_counts()[:6]

# %%
ax = sns.lineplot(x=a.index, y=a.values, marker="^", hue="")
plt.ylabel()

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# here, we can see above graphs that at 2 pm most of people watched videos on the social media.

# %%
b= df["Watch Reason"].value_counts()

# %%
ax = sns.countplot(data=df, x="Watch Reason")

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# as you can see above graphs that habit is most common reason behind watching video on the social media.

# %%
df["Self Control"].value_counts()
# Out:
# Self Control
# 8     248
# 5     228
# 10    180
# 7     159
# 9      60
# 3      55
# 6      36
# 4      34
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,4))
ax = sns.barplot(data=df, x="Profession", y="Self Control", errorbar=("ci",0))

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# most self control professions are waiting staff people while watching videos on the social media.

# %%
df["Addiction Level"].value_counts()
# Out:
# Addiction Level
# 2    248
# 5    228
# 0    180
# 3    159
# 1     60
# 7     55
# 4     36
# 6     34
# Name: count, dtype: int64

# %%
ax = sns.countplot(data=df, x="OS",  hue="ConnectionType")

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# Android's smart phone are most used by user through mobile data.

# %% [markdown]
# conclusion: male who used social media like tiktok and instagram from rural realm, they are students of india as well as cashier are the ones who spent too much time on the social media, and jokes/memes are liked, gaming is most importance to user, trends are most engaged, pranks are most time spent, no of comedy videos are most watched, facebook & instagram are most satified while watching videos by android's smart phone at evening and waiting staff is one of them who most self controlled while using social media, and it became habit of most of person using social media along with that people much losed productivity in their profession by watching video on youtube.
